# %%
# !pip install -q --upgrade pip
# !pip install -q botocore
# !pip install -q boto3

# %%
import boto3, json, base64

# %%
bedrock_runtime = boto3.client(
    service_name="bedrock-runtime",
    region_name="us-west-2"
)

# %%
prompt = "Generate image of Laguna Beach"

# %%
args = {
  "modelId": "stability.stable-diffusion-xl-v0",
  "contentType": "application/json",
  "accept": "application/json",
  "body": "{\"text_prompts\":[{\"text\":\"" + prompt + "\"}],\"cfg_scale\":10,\"seed\":0,\"steps\":50}"
}

print(args)
# Out:
# {'modelId': 'stability.stable-diffusion-xl-v0', 'contentType': 'application/json', 'accept': 'application/json', 'body': '{"text_prompts":[{"text":"Generate image of Laguna Beach"}],"cfg_scale":10,"seed":0,"steps":50}'}

# %%
response = bedrock_runtime.invoke_model(**args)

response
# Out:
# {'ResponseMetadata': {'RequestId': '302d69ea-854c-4bd8-a608-ca3384141382',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'date': 'Fri, 29 Sep 2023 01:44:41 GMT',
#    'content-type': 'application/json',
#    'content-length': '528354',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': '302d69ea-854c-4bd8-a608-ca3384141382'},
#   'RetryAttempts': 0},
#  'contentType': 'application/json',
#  'body': <botocore.response.StreamingBody at 0x1bb8d91f760>}

# %%
response_body = json.loads(response.get('body').read())

response_body
# Out:
# {'result': 'success',
#  'artifacts': [{'seed': 0,
#    'base64': '...',
#    'finishReason': 'SUCCESS'}]}

# %%
completion = response_body.get('artifacts')[0].get('base64')

img = base64.b64decode(completion)

filename = 'stable-diffusion.jpg'

with open(filename, 'wb') as f:
    f.write(img)
